# %%
from sklearn.datasets import fetch_california_housing
housing= datasets.fetch_california_housing()
housing;
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9352/3880939058.py in <module>
#       1 from sklearn.datasets import fetch_california_housing
# ----> 2 housing= datasets.fetch_california_housing()
#       3 housing;
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\datasets\_california_housing.py in fetch_california_housing(data_home, download_if_missing, return_X_y, as_frame)
#     132             ARCHIVE.url, data_home))
#     133
# --> 134         archive_path = _fetch_remote(ARCHIVE, dirname=data_home)
#     135
# ...

# %%
import sklearn
from sklearn import datasets

# %%
dir(datasets)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_base',
#  '_california_housing',
#  '_covtype',
#  '_kddcup99',
#  '_lfw',
#  '_olivetti_faces',
#  '_openml',
#  '_rcv1',
#  '_samples_generator',
#  '_species_distributions',
#  '_svmlight_format_fast',
#  '_svmlight_format_io',
#  '_twenty_newsgroups',
#  'clear_data_home',
#  'dump_svmlight_file',
#  'fetch_20newsgroups',
#  'fetch_20newsgroups_vectorized',
#  'fetch_california_housing',
#  'fetch_covtype',
#  'fetch_kddcup99',
#  'fetch_lfw_pairs',
#  'fetch_lfw_people',
#  'fetch_olivetti_faces',
#  'fetch_openml',
#  'fetch_rcv1',
#  'fetch_species_distributions',
#  'get_data_home',
#  'load_boston',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_sample_image',
#  'load_sample_images',
#  'load_svmlight_file',
#  'load_svmlight_files',
# ...

# %%
housing=datasets.fetch_covtype()
print(housing)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9352/3554916279.py in <module>
# ----> 1 housing=datasets.fetch_covtype()
#       2 print(housing)
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\datasets\_covtype.py in fetch_covtype(data_home, download_if_missing, random_state, shuffle, return_X_y, as_frame)
#     147         logger.info("Downloading %s" % ARCHIVE.url)
#     148
# --> 149         archive_path = _fetch_remote(ARCHIVE, dirname=covtype_dir)
# ...
